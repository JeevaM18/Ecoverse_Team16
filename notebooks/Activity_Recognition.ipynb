# %%
# !pip install -q scikeras joblib

# %%
import os
import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv1D, MaxPooling1D, LSTM,
    Dense, Dropout, BatchNormalization
)
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("niloy333/kuhar")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/niloy333/kuhar?dataset_version_number=1...
# 100%|██████████| 460M/460M [00:08<00:00, 56.7MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/niloy333/kuhar/versions/1

# %%
BASE_PATH = "/root/.cache/kagglehub/datasets/niloy333/kuhar/versions/1/2.Trimmed_interpolated_data"

# %%
CLASS_MAP = {
    "Walk": ["11.Walk", "12.Walk-backwards", "13.Walk-circle"],
    "Stairs": ["15.Stair-up", "16.Stair-down"],
    "Static": ["0.Stand", "1.Sit", "5.Lay"],
    "Transitions": ["4.Stand-sit", "6.Lay-stand"],
    "Exercise": ["8.Jump", "9.Push-up", "10.Sit-up", "14.Run"]
}

# %%
activity_to_group = {}
for group, acts in CLASS_MAP.items():
    for act in acts:
        activity_to_group[act] = group

# %%
X = []
y = []

for folder in sorted(os.listdir(BASE_PATH)):
    folder_path = os.path.join(BASE_PATH, folder)

    if folder not in activity_to_group:
        continue

    label = activity_to_group[folder]

    for file in os.listdir(folder_path):
        if file.endswith(".csv"):
            df = pd.read_csv(os.path.join(folder_path, file))
            df = df.select_dtypes(include=[np.number])
            X.append(df.values)
            y.append(label)

# %%
TIMESTEPS = 128   # good balance
X = np.array([sample[:TIMESTEPS] for sample in X if sample.shape[0] >= TIMESTEPS])
y = y[:len(X)]

print("X shape:", X.shape)  # (samples, timesteps, channels)
# Out:
# X shape: (1647, 128, 8)

# %%
num_samples, timesteps, channels = X.shape

X_reshaped = X.reshape(-1, channels)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_reshaped)

X = X_scaled.reshape(num_samples, timesteps, channels)

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_cat = to_categorical(y_encoded)

num_classes = y_cat.shape[1]
print("Classes:", le.classes_)
# Out:
# Classes: ['Exercise' 'Stairs' 'Static' 'Transitions' 'Walk']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_cat,
    test_size=0.2,
    random_state=42,
    stratify=y_encoded
)

# %%
model = Sequential([
    Conv1D(64, kernel_size=3, activation="relu", input_shape=(TIMESTEPS, channels)),
    BatchNormalization(),
    MaxPooling1D(2),

    Conv1D(128, kernel_size=3, activation="relu"),
    BatchNormalization(),
    MaxPooling1D(2),

    LSTM(64),
    Dropout(0.4),

    Dense(64, activation="relu"),
    Dropout(0.4),

    Dense(num_classes, activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_6 (Conv1D)               │ (None, 126, 64)        │         1,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 126, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 63, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 61, 128)        │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 61, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 30, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 80,965 (316.27 KB)
#  Trainable params: 80,581 (314.77 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
callbacks = [
    EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3)
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=40,
    batch_size=32,
    callbacks=callbacks
)
# Out:
# Epoch 1/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.4258 - loss: 1.3445 - val_accuracy: 0.5394 - val_loss: 1.3285 - learning_rate: 0.0010
# Epoch 2/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6697 - loss: 0.9096 - val_accuracy: 0.6364 - val_loss: 1.2710 - learning_rate: 0.0010
# Epoch 3/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.7667 - loss: 0.6672 - val_accuracy: 0.6152 - val_loss: 1.3370 - learning_rate: 0.0010
# Epoch 4/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.7802 - loss: 0.5640 - val_accuracy: 0.6091 - val_loss: 1.1746 - learning_rate: 0.0010
# Epoch 5/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8168 - loss: 0.5157 - val_accuracy: 0.6394 - val_loss: 0.7814 - learning_rate: 0.0010
# Epoch 6/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.8500 - loss: 0.4111 - val_accuracy: 0.7909 - val_loss: 0.5818 - learning_rate: 0.0010
# Epoch 7/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.8411 - loss: 0.4402 - val_accuracy: 0.7303 - val_loss: 0.6269 - learning_rate: 0.0010
# Epoch 8/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8585 - loss: 0.4200 - val_accuracy: 0.8515 - val_loss: 0.4270 - learning_rate: 0.0010
# Epoch 9/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9006 - loss: 0.2864 - val_accuracy: 0.8515 - val_loss: 0.4956 - learning_rate: 0.0010
# Epoch 10/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8815 - loss: 0.3230 - val_accuracy: 0.8394 - val_loss: 0.4311 - learning_rate: 0.0010
# Epoch 11/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9003 - loss: 0.3179 - val_accuracy: 0.8303 - val_loss: 0.4739 - learning_rate: 0.0010
# Epoch 12/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9006 - loss: 0.2981 - val_accuracy: 0.8545 - val_loss: 0.4050 - learning_rate: 5.0000e-04
# Epoch 13/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9279 - loss: 0.2257 - val_accuracy: 0.8545 - val_loss: 0.3960 - learning_rate: 5.0000e-04
# Epoch 14/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9420 - loss: 0.2005 - val_accuracy: 0.8727 - val_loss: 0.3785 - learning_rate: 5.0000e-04
# Epoch 15/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9443 - loss: 0.1785 - val_accuracy: 0.8848 - val_loss: 0.3601 - learning_rate: 5.0000e-04
# Epoch 16/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9562 - loss: 0.1573 - val_accuracy: 0.8727 - val_loss: 0.3590 - learning_rate: 5.0000e-04
# Epoch 17/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9468 - loss: 0.1656 - val_accuracy: 0.8788 - val_loss: 0.3575 - learning_rate: 5.0000e-04
# Epoch 18/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9426 - loss: 0.1836 - val_accuracy: 0.8758 - val_loss: 0.4190 - learning_rate: 5.0000e-04
# Epoch 19/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9499 - loss: 0.1921 - val_accuracy: 0.8758 - val_loss: 0.4153 - learning_rate: 5.0000e-04
# Epoch 20/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9623 - loss: 0.1360 - val_accuracy: 0.8970 - val_loss: 0.3684 - learning_rate: 5.0000e-04
# Epoch 21/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9702 - loss: 0.1272 - val_accuracy: 0.9000 - val_loss: 0.3675 - learning_rate: 2.5000e-04
# Epoch 22/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9583 - loss: 0.1192 - val_accuracy: 0.9000 - val_loss: 0.3803 - learning_rate: 2.5000e-04

# %%
y_pred = model.predict(X_test)
y_pred_cls = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

print("Accuracy:", accuracy_score(y_true, y_pred_cls))
print(classification_report(y_true, y_pred_cls, target_names=le.classes_))
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step
# Accuracy: 0.8787878787878788
#               precision    recall  f1-score   support
#
#     Exercise       0.92      0.90      0.91       102
#       Stairs       0.67      0.64      0.65        22
#       Static       0.86      1.00      0.92        54
#  Transitions       0.91      0.82      0.86        97
#         Walk       0.86      0.91      0.88        55
#
#     accuracy                           0.88       330
#    macro avg       0.84      0.85      0.85       330
# weighted avg       0.88      0.88      0.88       330

# %%
model.save("kuhar_cnn_lstm_fixed.h5")

import pickle
with open("kuhar_label_encoder.pkl", "wb") as f:
    pickle.dump(le, f)

with open("kuhar_scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from google.colab import files
files.download("kuhar_label_encoder.pkl")
